# %%
import pandas as pd
import geopandas as gpd
from shapely.geometry import Point
import glob,os
from shapely.ops import nearest_points
from shapely.ops import unary_union

# %%
import geopandas as gpd
from geopy.distance import geodesic

# Load the GeoDataFrame with your points
gdf = gpd.read_file('C:/Users/anranzheng/Dropbox (UFL)/Mobility Hub/Data/arcgis online/selected_center_pt15.shp')

# %%
selected_ids = []

while len(gdf) > 0:
    #gdf = gdf.sort_values(by='score', ascending=False)
    
     # Find the point with the highest value
    highest_point = gdf.loc[gdf['score'].idxmax()]

    # Store its ID in the list
    selected_ids.append(highest_point['index'])

    # Select the point for which you want to calculate distances (e.g., the first point)
    point_to_measure = highest_point['geometry']

    # Create an empty list to store distances
    distances = []

    # Loop through all the points in the GeoDataFrame
    for _, row in gdf.iterrows():
        # Calculate the distance between the selected point and the current point
        
        dist = distance.euclidean(
       (point_to_measure.x, point_to_measure.y),
        (row.geometry.x, row.geometry.y))
        distances.append(dist)

    # Add the distances as a new column in the GeoDataFrame
    gdf['distance_to_point'] = distances
    
    #eculidan distance - 0.5 mile: 0.0155
    # *1.5 = 0.02325
    gdf=gdf[gdf['distance_to_point']>=0.02325]
    
    #print(len(gdf))

# %%
len(selected_ids)
# Out:
# 18

# %%
gdf2 = gpd.read_file('C:/Users/anranzheng/Dropbox (UFL)/Mobility Hub/Anran/module builder/results/more_criteria/new_criteria_buffer.shp')

# %%
gdf2[gdf2['index'].isin(selected_ids)].to_file('C:/Users/anranzheng/Dropbox (UFL)/Mobility Hub/Data/results/code_updated_results_1_5/access.shp')

# %%
gdf2[gdf2['index'].isin(selected_ids)].sort_values('score').tail(5).to_file('C:/Users/anranzheng/Dropbox (UFL)/Mobility Hub/Data/results/code_updated_results_1_5/score8.shp')

# %%
gdf2[gdf2['index'].isin(selected_ids)].sort_values('socio_c').tail(5)
# Out:
#      index  inner_micr  Route  total_trip  Total_Acti  W_C_TOTAL  BIKE_TOTAL  \
# 374    374    0.000000    8.0   19.874804    3.943947   0.000000   13.920286
# 450    450    0.000000    4.0    3.688799    0.202254   0.393064    0.773349
# 528    528   11.884589    4.0    0.335345    0.202254   0.046243    0.000000
# 270    270   31.577742   16.0    3.420523    0.144467   0.971098    0.178465
# 235    235   43.714220   60.0   32.819137   11.499567   6.959538   30.696014
# 524    524   81.337302    8.0    0.670691    0.057787   0.023121    0.178465
# 514    514   64.369132    4.0    0.335345    0.043340   0.046243    0.000000
# 326    326   92.603618    4.0    0.737760    0.086680   0.000000    0.000000
#
#      inner_scoo      RENT%       bike  ...  infast_ind  socio_inde  \
# 374    4.360892  84.998549  76.064090  ...   27.091463   48.680495
# 450    0.558286  51.820029  37.933556  ...   25.480819   58.284592
# 528    2.797451  35.980421  67.892768  ...   52.594942   57.112453
# ...

# %%
gdf3 = gpd.read_file('C:/Users/anranzheng/Dropbox (UFL)/Mobility Hub/Data/results/code_updated_results_1_5/ridership.shp')

# %%
gdf4 = gpd.read_file('C:/Users/anranzheng/Dropbox (UFL)/Mobility Hub/Data/gnv/existing_mhub.shp')

# %%
gdf2 = gpd.read_file('C:/Users/anranzheng/Dropbox (UFL)/Mobility Hub/Anran/module builder/results/more_criteria/new_criteria_buffer.shp')

# %%
gdf4.columns
# Out:
# Index(['index', 'inner_micr', 'Route', 'total_trip', 'Total_Acti', 'W_C_TOTAL',
#        'BIKE_TOTAL', 'inner_scoo', 'HISPANIC_', 'VEHICLE_0_', 'AGE_65_UP_',
#        'DIS_2064_', 'S_NOTATALL', 'BELOW_POV_', 'BLACK_', 'RENT_', 'bike',
#        'bike_osm', 'sidewalk', 'sidewalk_o', 'fmlm_score', 'bus_stop_n',
#        'Walkscore1', 'D3BMM4', 'D3BPO4', 'D5AR', 'D5BR', 'ridership_',
#        'FMLM_index', 'infast_ind', 'socio_inde', 'access_ind', 'score',
#        'geometry'],
#       dtype='object')

# %%
exist_hub=gdf2[(gdf2['index']==225)|(gdf2['index']==246)|(gdf2['index']==255)]

# %%
exist_hub.columns
# Out:
# Index(['index', 'inner_micr', 'Route', 'total_trip', 'Total_Acti', 'W_C_TOTAL',
#        'BIKE_TOTAL', 'inner_scoo', 'RENT%', 'bike', 'bike_osm', 'sidewalk',
#        'sidewalk_o', 'bus_stop_n', 'Walkscore1', 'D3BMM4', 'D3BPO4', 'D5AR',
#        'D5BR', 'VEHICLE_0%', 'DIS_2064%', 'BELOW_POV%', 'BLACK%', 'fmlm_score',
#        'ridership_', 'FMLM_index', 'infast_ind', 'socio_inde', 'access_ind',
#        'score', 'fmlm_c', 'ridershi_1', 'infast_c', 'socio_c', 'access_c',
#        'geometry'],
#       dtype='object')

# %%
exist_hub=exist_hub[['index', 'inner_micr', 'Route', 'total_trip', 'Total_Acti', 'W_C_TOTAL',
       'BIKE_TOTAL', 'inner_scoo', 'VEHICLE_0%', 'DIS_2064%', 'BELOW_POV%', 'BLACK%','sidewalk', 'sidewalk_o', 'bus_stop_n',
       'Walkscore1', 'D3BPO4', 'D5AR', 'D5BR', 'ridershi_1',
       'FMLM_index', 'infast_ind', 'socio_inde', 'access_ind', 'ridershi_1',
       'geometry', 'RENT%']]

# %%
score9=gdf3[gdf3['index'].isin(selected_ids)].sort_values('score').tail(9)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 score9=gdf3[gdf3['index'].isin(selected_ids)].sort_values('score').tail(9)
#
# NameError: name 'selected_ids' is not defined

# %%
exist_hub.columns
# Out:
# Index(['index', 'inner_micr', 'Route', 'total_trip', 'Total_Acti', 'W_C_TOTAL',
#        'BIKE_TOTAL', 'inner_scoo', 'VEHICLE_0%', 'DIS_2064%', 'BELOW_POV%',
#        'BLACK%', 'sidewalk', 'sidewalk_o', 'bus_stop_n', 'Walkscore1',
#        'D3BPO4', 'D5AR', 'D5BR', 'ridershi_1', 'FMLM_index', 'infast_ind',
#        'socio_inde', 'access_ind', 'score', 'geometry', 'RENT%'],
#       dtype='object')

# %%
exist_hub=exist_hub[['index', 'inner_micr', 'Route', 'total_trip', 'Total_Acti', 'W_C_TOTAL',
       'BIKE_TOTAL', 'inner_scoo', 'VEHICLE_0%', 'DIS_2064%', 'BELOW_POV%', 'BLACK%','sidewalk', 'sidewalk_o', 'bus_stop_n',
       'Walkscore1', 'D3BPO4', 'D5AR', 'D5BR', 
       'geometry', 'RENT%']]

# %%
score9=score9[['index', 'inner_micr', 'Route', 'total_trip', 'Total_Acti', 'W_C_TOTAL',
       'BIKE_TOTAL', 'inner_scoo', 'VEHICLE_0%', 'DIS_2064%', 'BELOW_POV%', 'BLACK%','sidewalk', 'sidewalk_o', 'bus_stop_n',
       'Walkscore1', 'D3BPO4', 'D5AR', 'D5BR', 
       'geometry', 'RENT%']]

# %%
#df4=
score=pd.concat([score9,exist_hub],axis=0,ignore_index=True)

# %%
score.to_file('C:/Users/anranzheng/Dropbox (UFL)/Mobility Hub/Data/results/regional/accessibility/access.shp')

# %%
score= gpd.read_file('C:/Users/anranzheng/Dropbox (UFL)/Mobility Hub/Data/results/regional/accessibility/access.shp')

# %%
smart_location=gpd.read_file('C:/Users/anranzheng/Dropbox (UFL)/Mobility Hub/Data/results/regional/smart_location.shp')[['D3BMM4', 'geometry']]

# %%
smart_location.to_file('C:/Users/anranzheng/Dropbox (UFL)/Mobility Hub/Data/results/regional/smart_location2.shp')

# %%
#fmlm

# %%
origin= gpd.read_file('C:/Users/anranzheng/Dropbox (UFL)/Mobility Hub/Data/results/regional/accessibility/centroid_access.shp')
stop= gpd.read_file('C:/Users/anranzheng/Dropbox (UFL)/Gap analysis/data/rt GTFS data/stops.shp')

# %%
origin['job/pop']=origin['C000']/origin['totalPp']

import numpy as np
origin=origin.replace([np.inf, -np.inf], np.nan)
origin=origin[origin['job/pop']!=0].dropna(subset=['job/pop'])
origin['job/pop'].describe()

# %%
origin.to_file('C:/Users/anranzheng/Dropbox (UFL)/Mobility Hub/Data/results/regional/fmlm/origin2.shp')

# %%
origin= gpd.read_file('C:/Users/anranzheng/Dropbox (UFL)/Mobility Hub/Data/results/regional/ridership/join.shp')

# %%
origin
# Out:
#        Join_Count  TARGET_FID  JOIN_FID            GEOID  \
# 0               1           0         1  120010010003009
# 1               1           0         2  120010010003009
# 2               1           0         3  120010010003009
# 3               1           0         4  120010010003009
# 4               1           0        11  120010010003009
# ...           ...         ...       ...              ...
# 12674           1        2885         2  120010010002026
# 12675           1        2885         3  120010010002026
# 12676           1        2885         5  120010010002026
# 12677           1        2885         9  120010010002026
# 12678           1        2885        10  120010010002026
#
#                                                     NAME  educatd  nnhspnc  \
# 0      Block 3009, Block Group 3, Census Tract 10, Al...      0.0     37.0
# 1      Block 3009, Block Group 3, Census Tract 10, Al...      0.0     37.0
# ...

# %%
origin.NEAR_DIST=origin.NEAR_DIST*100/1.61
def assign_value(origin):

    if origin.NEAR_DIST <= 0.75:
        return 0
    elif origin.NEAR_DIST > 0.75 and  origin.NEAR_DIST <= 1.5:
        return 1
    elif origin.NEAR_DIST > 1.5 and  origin.NEAR_DIST <= 2.25:
        return 2
    else:
        return 3

# Apply the 'assign_value' function to each row of the DataFrame
origin['recode'] = origin.apply(assign_value, axis=1)

# %%
origin.to_file('C:/Users/anranzheng/Dropbox (UFL)/Mobility Hub/Data/results//regional/ridership/origin_ridership.shp')

# %%
origin= gpd.read_file('C:/Users/anranzheng/Dropbox (UFL)/Mobility Hub/Data/results/regional/accessibility/origin3_spatialjoin.shp')

# %%
origin['job/pop']=origin['C000']/origin['totalPp']

import numpy as np
origin=origin.replace([np.inf, -np.inf], np.nan)
origin=origin[origin['job/pop']!=0].dropna(subset=['job/pop'])
origin['job/pop'].describe()
# Out:
# count    3245.000000
# mean        3.958898
# std        30.546632
# min         0.000678
# 25%         0.052632
# 50%         0.207547
# 75%         1.059524
# max       562.526316
# Name: job/pop, dtype: float64

# %%
origin['fmlm_score']=origin['job_pop']*origin['recode']

sum_score=origin.groupby(['index'])['fmlm_score'].sum().reset_index()

# %%
sum_score
# Out:
#     index  fmlm_score
# 0     179   38.146169
# 1     225    8.033122
# 2     235    0.118919
# 3     246    0.025097
# 4     255    0.062727
# 5     270    0.042764
# 6     302    0.164991
# 7     326   18.477548
# 8     363    7.333333
# 9     374    6.873982
# 10    524   12.115197
# 11    612    5.203120

# %%
#bicycle length
folder_path = 'C:/Users/anranzheng/Dropbox (UFL)/Mobility Hub/Data/results/regional/bike6'

shapefile_list = [file for file in os.listdir(folder_path) if file.endswith('.shp')]

merged_gdf = gpd.GeoDataFrame()

for shapefile in shapefile_list:
    gdf = gpd.read_file(os.path.join(folder_path, shapefile))
    
    merged_gdf = merged_gdf.append(gdf, ignore_index=True)
# Out:
# C:\Users\anranzheng\AppData\Local\Temp\ipykernel_31696\1568364928.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   merged_gdf = merged_gdf.append(gdf, ignore_index=True)
# C:\Users\anranzheng\AppData\Local\Temp\ipykernel_31696\1568364928.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   merged_gdf = merged_gdf.append(gdf, ignore_index=True)
# C:\Users\anranzheng\AppData\Local\Temp\ipykernel_31696\1568364928.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   merged_gdf = merged_gdf.append(gdf, ignore_index=True)
# ...

# %%
bike=merged_gdf.groupby(['index'])['Shape_Leng'].sum().reset_index()

# %%
#osm
folder_path = 'C:/Users/anranzheng/Dropbox (UFL)/Mobility Hub/Data/results/regional/osm6'

shapefile_list = [file for file in os.listdir(folder_path) if file.endswith('.shp')]

merged_gdf2 = gpd.GeoDataFrame()

for shapefile in shapefile_list:
    gdf = gpd.read_file(os.path.join(folder_path, shapefile))
    
    merged_gdf2 = merged_gdf2.append(gdf, ignore_index=True)
# Out:
# C:\Users\anranzheng\AppData\Local\Temp\ipykernel_31696\901231665.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   merged_gdf2 = merged_gdf2.append(gdf, ignore_index=True)
# C:\Users\anranzheng\AppData\Local\Temp\ipykernel_31696\901231665.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   merged_gdf2 = merged_gdf2.append(gdf, ignore_index=True)
# C:\Users\anranzheng\AppData\Local\Temp\ipykernel_31696\901231665.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   merged_gdf2 = merged_gdf2.append(gdf, ignore_index=True)
# ...

# %%
osm=merged_gdf2.groupby(['index'])['Shape_Le_1'].sum().reset_index()

# %%
#left join osm with sidewalk and bicycle 
df2 = pd.merge(osm,bike,how='left',on='index')
df2['bike_osm']=df2['Shape_Leng']/df2['Shape_Le_1']
df2=df2.rename(columns={'Shape_Leng':'bike'})
df_all=pd.merge(df2,sum_score,how='left',on='index')

# %%
folder_path = 'C:/Users/anranzheng/Dropbox (UFL)/Mobility Hub/Data/results/regional/access6'

shapefile_list = [file for file in os.listdir(folder_path) if file.endswith('.shp')]

merged_gdf4 = gpd.GeoDataFrame()

for shapefile in shapefile_list:
    gdf = gpd.read_file(os.path.join(folder_path, shapefile))
    #print(shapefile)
    merged_gdf4 = merged_gdf4.append(gdf, ignore_index=True)
# Out:
# C:\Users\anranzheng\AppData\Local\Temp\ipykernel_31696\842705506.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   merged_gdf4 = merged_gdf4.append(gdf, ignore_index=True)
# C:\Users\anranzheng\AppData\Local\Temp\ipykernel_31696\842705506.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   merged_gdf4 = merged_gdf4.append(gdf, ignore_index=True)
# C:\Users\anranzheng\AppData\Local\Temp\ipykernel_31696\842705506.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   merged_gdf4 = merged_gdf4.append(gdf, ignore_index=True)
# ...

# %%
inter_den=merged_gdf4.groupby(['index'])['D3BMM4'].mean().reset_index()

#merge 
final2 = pd.merge(inter_den,df_all,how='left',on='index')

# %%
buffer3= gpd.read_file('C:/Users/anranzheng/Dropbox (UFL)/Mobility Hub/Data/results/regional/score/score_3mile.shp')

# %%
score.columns
# Out:
# Index(['index', 'inner_micr', 'Route', 'total_trip', 'Total_Acti', 'W_C_TOTAL',
#        'BIKE_TOTAL', 'inner_scoo', 'RENT%', 'bike', 'bike_osm', 'sidewalk',
#        'sidewalk_o', 'bus_stop_n', 'Walkscore1', 'D3BMM4', 'D3BPO4', 'D5AR',
#        'D5BR', 'VEHICLE_0%', 'DIS_2064%', 'BELOW_POV%', 'BLACK%', 'fmlm_score',
#        'ridership_', 'FMLM_index', 'infast_ind', 'socio_inde', 'access_ind',
#        'score', 'fmlm_c', 'ridershi_1', 'infast_c', 'socio_c', 'access_c',
#        'geometry'],
#       dtype='object')

# %%
final2.columns
# Out:
# Index(['index', 'D3BMM4', 'Shape_Le_1', 'bike', 'bike_osm', 'fmlm_score'], dtype='object')

# %%
final3.columns
# Out:
# Index(['index', 'inner_micr', 'Route', 'total_trip', 'Total_Acti', 'W_C_TOTAL',
#        'BIKE_TOTAL', 'inner_scoo', 'VEHICLE_0%', 'DIS_2064%', 'BELOW_POV%',
#        'BLACK%', 'sidewalk', 'sidewalk_o', 'bus_stop_n', 'Walkscore1',
#        'D3BPO4', 'D5AR', 'D5BR', 'geometry', 'RENT%', 'D3BMM4', 'bike',
#        'bike_osm', 'fmlm_score'],
#       dtype='object')

# %%
score=score[['index', 'inner_micr', 'Route', 'total_trip', 'Total_Acti', 'W_C_TOTAL',
       'BIKE_TOTAL', 'inner_scoo', 'VEHICLE_0%', 'DIS_2064%', 'BELOW_POV%',
       'BLACK%', 'sidewalk', 'sidewalk_o', 'bus_stop_n', 'Walkscore1',
       'D3BPO4', 'D5AR', 'D5BR', 'geometry', 'RENT%']]

# %%
final2
# Out:
#     index     D3BMM4    Shape_Le_1           bike  bike_osm  fmlm_score
# 0   179.0   1.532417  5.766706e+05  101258.730121  0.175592   38.146169
# 1   225.0   3.019677  1.019103e+06  215963.168112  0.211915    8.033122
# 2   235.0   7.141665  1.210765e+06  279684.095509  0.230998    0.118919
# 3   246.0   8.051877  1.074951e+06  226914.122429  0.211093    0.025097
# 4   255.0   9.384924  8.257936e+05  157893.843792  0.191203    0.062727
# 5   270.0  10.228917  6.271829e+05  115690.232702  0.184460    0.042764
# 6   302.0   2.656265  9.979065e+05  177565.948427  0.177938    0.164991
# 7   326.0   3.053931  6.911568e+05  118409.912303  0.171321   18.477548
# 8   363.0   7.252429  1.232580e+06  281894.667217  0.228703    7.333333
# 9   374.0   4.955243  8.358876e+05  218724.920181  0.261668    6.873982
# 10  524.0   9.243978  5.133805e+05   98153.212266  0.191190   12.115197
# 11  612.0   2.232134  9.096618e+05  113892.238124  0.125203    5.203120

# %%
score
# Out:
#     index  inner_micr  Route  total_trip  Total_Acti  W_C_TOTAL  BIKE_TOTAL  \
# 0     179    0.000000    4.0    2.995752    0.462294   0.809249    0.059488
# 1     612    0.000000   12.0    3.822938    0.144467   0.115607    0.000000
# 2     374    0.000000    8.0   19.874804    3.943947   0.000000   13.920286
# 3     270   31.577742   16.0    3.420523    0.144467   0.971098    0.178465
# 4     363    0.000000    4.0    2.973396    0.404507   0.693642    1.606187
# 5     524   81.337302    8.0    0.670691    0.057787   0.023121    0.178465
# 6     326   92.603618    4.0    0.737760    0.086680   0.000000    0.000000
# 7     235   43.714220   60.0   32.819137   11.499567   6.959538   30.696014
# 8     302   46.393405    4.0    0.737760    0.231147   0.000000    0.000000
# 9     225    0.000000   28.0   27.162978    1.791390   2.057803    1.487210
# 10    246   12.205175   32.0    4.806617    5.561976  12.115607    2.498513
# ...

# %%
final3
# Out:
#     index  inner_micr  Route  total_trip  Total_Acti  W_C_TOTAL  BIKE_TOTAL  \
# 0     627    0.000000    4.0    0.201207    0.014447   0.000000    0.000000
# 1     363    0.000000    4.0    2.973396    0.404507   0.693642    1.606187
# 2     374    0.000000    8.0   19.874804    3.943947   0.000000   13.920286
# 3     450    0.000000    4.0    3.688799    0.202254   0.393064    0.773349
# 4     528   11.884589    4.0    0.335345    0.202254   0.046243    0.000000
# 5     270   31.577742   16.0    3.420523    0.144467   0.971098    0.178465
# 6     235   43.714220   60.0   32.819137   11.499567   6.959538   30.696014
# 7     524   81.337302    8.0    0.670691    0.057787   0.023121    0.178465
# 8     326   92.603618    4.0    0.737760    0.086680   0.000000    0.000000
# 9     225    0.000000   28.0   27.162978    1.791390   2.057803    1.487210
# 10    246   12.205175   32.0    4.806617    5.561976  12.115607    2.498513
# ...

# %%
final3=pd.merge(score,final2,how='left',on='index')[['index', 'inner_micr', 'Route', 'total_trip', 'Total_Acti', 'W_C_TOTAL',
       'BIKE_TOTAL', 'inner_scoo', 'VEHICLE_0%', 'DIS_2064%', 'BELOW_POV%',
       'BLACK%', 'sidewalk', 'sidewalk_o', 'bus_stop_n', 'Walkscore1',
       'D3BPO4', 'D5AR', 'D5BR', 'geometry', 'RENT%', 'D3BMM4', 'bike', 'bike_osm', 'fmlm_score']]

#normalize the selected columns and save to a new df
def normalize(df):
    result = df.copy()
    for feature_name in df.columns:
        max_value = df[feature_name].max()
        min_value = df[feature_name].min()
        result[feature_name] = 100*(df[feature_name] - min_value) / (max_value - min_value)
    return result

df_norm=normalize(final3[['inner_micr', 'Route', 'total_trip', 'Total_Acti', 'W_C_TOTAL',
       'BIKE_TOTAL', 'inner_scoo', 'VEHICLE_0%', 'DIS_2064%', 'BELOW_POV%',
       'BLACK%', 'sidewalk', 'sidewalk_o', 'bus_stop_n', 'Walkscore1',
       'D3BPO4', 'D5AR', 'D5BR', 'RENT%', 'D3BMM4', 'bike', 'bike_osm', 'fmlm_score']])

df_norm['ridership_index']=0.4*df_norm.Total_Acti+0.1*df_norm.W_C_TOTAL+0.1*df_norm.Route+0.1*df_norm.bus_stop_n+0.3*df_norm.total_trip
df_norm['FMLM_index']=0.15*df_norm.inner_micr+0.15*df_norm.inner_scoo+0.15*df_norm.BIKE_TOTAL+0.55*df_norm.fmlm_score
df_norm['infast_index']=0.16*(df_norm.bike_osm+df_norm.bike+df_norm.sidewalk_o+df_norm.sidewalk+df_norm.D3BMM4+df_norm.D3BPO4)
df_norm['socio_index']=0.2*(df_norm['VEHICLE_0%']+df_norm['DIS_2064%']+df_norm['BELOW_POV%']+df_norm['BLACK%']+df_norm['RENT%'])
df_norm['access_index']=0.2*df_norm.D5AR+0.3*df_norm.D5BR+0.5*df_norm.Walkscore1

df_norm['score']=0.5*df_norm['access_index']+0.125*(df_norm['socio_index']+df_norm['ridership_index']+df_norm['infast_index']+df_norm['FMLM_index'])

df_norm =df_norm.sort_values(by='score', ascending=False).head(4)

# %%
df_norm
# Out:
#    inner_micr       Route  total_trip  Total_Acti  W_C_TOTAL  BIKE_TOTAL  \
# 7   47.205737  100.000000  100.000000  100.000000  57.442748  100.000000
# 8   50.098912    0.000000    0.208623    1.515152   0.000000    0.000000
# 6  100.000000    0.000000    0.208623    0.252525   0.000000    0.000000
# 5   87.833828    7.142857    0.000000    0.000000   0.190840    0.581395
#
#    inner_scoo  VEHICLE_0%  DIS_2064%  BELOW_POV%  ...     D3BMM4       bike  \
# 7  100.000000   65.550831   0.000000   65.209884  ...  64.500066  98.796912
# 8   78.685411   57.997362  21.654749   68.913010  ...  12.922988  43.219825
# 6   21.902691   77.974706  58.065603   84.783791  ...  17.495703  11.024567
# 5   19.273636   77.255826  64.469273   66.574335  ...  88.674302   0.000000
#
#     bike_osm  fmlm_score  ridership_index  FMLM_index  infast_index  \
# 7  77.525406    0.246117        95.744275   37.216225     75.576097
# 8  38.644060    0.366974         9.583376   19.519484     63.110831
# ...

# %%
df_norm.ridership_index.describe()
# Out:
# count    17.000000
# mean     14.519476
# std      20.783527
# min       0.704518
# 25%       5.023738
# 50%       8.802066
# 75%      11.565335
# max      90.000000
# Name: ridership_index, dtype: float64

# %%
df_norm.score.describe()
# Out:
# count     9.000000
# mean     32.622126
# std       4.561263
# min      23.096380
# 25%      30.584477
# 50%      33.355728
# 75%      34.624337
# max      38.333011
# Name: score, dtype: float64

# %%
df_norm
# Out:
#     inner_micr       Route  total_trip  Total_Acti   W_C_TOTAL  BIKE_TOTAL  \
# 0     0.000000    0.000000    0.000000    1.547619    0.854701    6.391753
# 1     0.000000    4.761905    3.561935    3.333333   29.914530    0.206186
# 2    34.099901   19.047619    4.066986    0.714286   35.897436    0.618557
# 3     0.000000   23.809524   12.519936   16.904762  100.000000  100.000000
# 4    50.098912    4.761905    0.877193    1.428571    0.000000    0.000000
# 5   100.000000    4.761905    0.877193    0.238095    0.000000    0.000000
# 6     0.000000    4.761905    3.535354    0.238095   11.965812    0.000000
# 7     0.000000    4.761905    3.535354    2.857143   25.641026    5.567010
# 8     0.000000    9.523810   23.631047   32.023810    0.000000   48.247423
# 9     0.000000  100.000000  100.000000  100.000000    0.000000   47.216495
# 10    0.000000    4.761905    4.385965    1.190476   14.529915    2.680412
# ...

# %%
df_norm
# Out:
#     inner_micr     Route  total_trip  Total_Acti  W_C_TOTAL  BIKE_TOTAL  \
# 5   100.000000  4.761905    0.877193    0.238095   0.000000    0.000000
# 12   87.833828  9.523810    0.797448    0.000000   0.854701    0.618557
# 4    50.098912  4.761905    0.877193    1.428571   0.000000    0.000000
# 8     0.000000  9.523810   23.631047   32.023810   0.000000   48.247423
#
#     inner_scoo  VEHICLE_0%  DIS_2064%  BELOW_POV%  ...     D3BMM4       bike  \
# 5    25.295520  100.000000  64.621169   87.041634  ...   5.251345  10.569034
# 12   22.259211   99.156936  69.966243   71.534172  ...  86.993470   0.000000
# 4    90.874147   76.571641  34.229423   73.525824  ...   0.000000  41.433990
# 8     5.107064   68.826941  18.444001  100.000000  ...  30.358957  62.908890
#
#       bike_osm  fmlm_score  ridership_index  FMLM_index  infast_index  \
# 5     0.000000  100.000000         8.802066   73.794328     45.053337
# 12   21.991624   65.567127         9.813671   52.668659     58.489060
# ...

# %%
result2
# Out:
#     index                                           geometry
# 0     161  POLYGON ((-82.38667 29.71739, -82.38550 29.717...
# 1     179  POLYGON ((-82.42051 29.61460, -82.41935 29.614...
# 2     270  POLYGON ((-82.30529 29.60585, -82.30645 29.605...
# 3     291  POLYGON ((-82.37393 29.63603, -82.37509 29.636...
# 4     302  POLYGON ((-82.40818 29.64145, -82.40935 29.641...
# 5     326  POLYGON ((-82.35540 29.69474, -82.35657 29.694...
# 6     350  POLYGON ((-82.36557 29.67407, -82.36673 29.674...
# 7     363  POLYGON ((-82.33867 29.65608, -82.33983 29.656...
# 8     374  POLYGON ((-82.35936 29.59915, -82.36052 29.599...
# 9     390  POLYGON ((-82.34913 29.62496, -82.35030 29.624...
# 10    450  POLYGON ((-82.32206 29.67389, -82.32322 29.673...
# 11    513  POLYGON ((-82.43875 29.65908, -82.43992 29.659...
# 12    524  POLYGON ((-82.27962 29.66573, -82.28079 29.665...
# 13    528  POLYGON ((-82.30533 29.65720, -82.30649 29.657...
# ...

# %%
score_df
# Out:
#     index                                           geometry  inner_micr  \
# 4     302  POLYGON ((-82.40818 29.64145, -82.40935 29.641...   50.098912
# 5     326  POLYGON ((-82.35540 29.69474, -82.35657 29.694...  100.000000
# 8     374  POLYGON ((-82.35936 29.59915, -82.36052 29.599...    0.000000
# 12    524  POLYGON ((-82.27962 29.66573, -82.28079 29.665...   87.833828
#
#        Route  total_trip  Total_Acti  W_C_TOTAL  BIKE_TOTAL  inner_scoo  \
# 4   4.761905    0.877193    1.428571   0.000000    0.000000   90.874147
# 5   4.761905    0.877193    0.238095   0.000000    0.000000   25.295520
# 8   9.523810   23.631047   32.023810   0.000000   48.247423    5.107064
# 12  9.523810    0.797448    0.000000   0.854701    0.618557   22.259211
#
#     VEHICLE_0%  ...     D3BMM4       bike    bike_osm  fmlm_score  \
# 4    76.571641  ...   0.000000  41.433990    7.324168    0.892927
# 5   100.000000  ...   5.251345  10.569034    0.000000  100.000000
# ...

# %%
result2=final3[['index','geometry']]

score_df=pd.concat([result2,df_norm],axis=1)

score_df=score_df.dropna()

score_df.to_file('C:/Users/anranzheng/Dropbox (UFL)/Mobility Hub/Data/results/district/access4.shp')
# Out:
# C:\Users\anranzheng\AppData\Local\Temp\ipykernel_31696\3070652807.py:7: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   score_df.to_file('C:/Users/anranzheng/Dropbox (UFL)/Mobility Hub/Data/results/district/access4.shp')

# %%
score_df.columns
# Out:
# Index(['index', 'geometry', 'inner_micr', 'Route', 'total_trip', 'Total_Acti',
#        'W_C_TOTAL', 'BIKE_TOTAL', 'inner_scoo', 'VEHICLE_0%', 'DIS_2064%',
#        'BELOW_POV%', 'BLACK%', 'sidewalk', 'sidewalk_o', 'bus_stop_n',
#        'Walkscore1', 'D3BPO4', 'D5AR', 'D5BR', 'RENT%', 'D3BMM4', 'bike',
#        'bike_osm', 'fmlm_score', 'ridership_index', 'FMLM_index',
#        'infast_index', 'socio_index', 'access_index', 'score'],
#       dtype='object')

# %%
#calculate
score_df['access_index2']=0.33*(score_df.D5AR+score_df.D5BR+score_df.Walkscore1)

score_df['score2']=0.5*score_df['access_index2']+0.125*(score_df['ridership_index']+score_df['FMLM_index']+score_df['infast_index']+score_df['socio_index'])

score_df.sort_values(by='score2', ascending=False).head(1).to_file('C:/Users/anranzheng/Dropbox (UFL)/Mobility Hub/Data/results/regional/accessibility/access1.shp')

# %%
#revise fmlm of score
origin= gpd.read_file('C:/Users/anranzheng/Dropbox (UFL)/Mobility Hub/Data/results/regional/score/upated_fmlm/census_centroid.shp')

# %%
origin['job/pop']=origin['C000']/origin['totalPp']

import numpy as np
origin=origin.replace([np.inf, -np.inf], np.nan)
origin=origin[origin['job/pop']!=0].dropna(subset=['job/pop'])

# %%
origin.NEAR_DIST=origin.NEAR_DIST*100/1.61
def assign_value(origin):

    if origin.NEAR_DIST <= 0.75:
        return 0
    elif origin.NEAR_DIST > 0.75 and  origin.NEAR_DIST <= 1.5:
        return 1
    elif origin.NEAR_DIST > 1.5 and  origin.NEAR_DIST <= 2.25:
        return 2
    else:
        return 3

# Apply the 'assign_value' function to each row of the DataFrame
origin['recode'] = origin.apply(assign_value, axis=1)

# %%
origin
# Out:
#                 GEOID                                               NAME  \
# 5     120010003022003  Block 2003, Block Group 2, Census Tract 3.02, ...
# 8     120010004002002  Block 2002, Block Group 2, Census Tract 4, Ala...
# 12    120010005005001  Block 5001, Block Group 5, Census Tract 5, Ala...
# 15    120010003012051  Block 2051, Block Group 2, Census Tract 3.01, ...
# 17    120010018112030  Block 2030, Block Group 2, Census Tract 18.11,...
# ...               ...                                                ...
# 2878  120010019021013  Block 1013, Block Group 1, Census Tract 19.02,...
# 2879  120010016056026  Block 6026, Block Group 6, Census Tract 16.05,...
# 2882  120010022041000  Block 1000, Block Group 1, Census Tract 22.04,...
# 2883  120010008081003  Block 1003, Block Group 1, Census Tract 8.08, ...
# 2884  120010014002010  Block 2010, Block Group 2, Census Tract 14, Al...
#
#       educatd  nnhspnc  totalPp    C000   CA01   CA02   CA03   CE01  ...  \
# ...

# %%
origin.to_file('C:/Users/anranzheng/Dropbox (UFL)/Mobility Hub/Data/results/regional/score/upated_fmlm/origin3.shp')

# %%
origin= gpd.read_file('C:/Users/anranzheng/Dropbox (UFL)/Mobility Hub/Data/results/regional/ridership/origin_spatial5.shp')

# %%
origin['fmlm_score']=origin['job_pop']*origin['recode']
sum_score=origin.groupby(['index'])['fmlm_score'].sum().reset_index()

# %%
sum_score
# Out:
#     index  fmlm_score
# 0   225.0    8.033122
# 1   246.0    0.025097
# 2   255.0    0.062727
# 3   270.0    0.042764
# 4   291.0    0.000000
# 5   302.0    0.164991
# 6   326.0   18.477548
# 7   363.0    7.333333
# 8   374.0    6.873982
# 9   450.0    9.357007
# 10  524.0   12.115197
# 11  528.0    8.659341

# %%
origin= gpd.read_file('C:/Users/anranzheng/Dropbox (UFL)/Mobility Hub/Data/results/regional/score/upated_fmlm/neighbourhood.shp')

# %%
origin.columns
# Out:
# Index(['OBJECTID', 'index', 'inner_micr', 'Route', 'total_trip', 'Total_Acti',
#        'W_C_TOTAL', 'BIKE_TOTAL', 'inner_scoo', 'VEHICLE_0_', 'DIS_2064_',
#        'BELOW_POV_', 'BLACK_', 'sidewalk', 'sidewalk_o', 'bus_stop_n',
#        'Walkscore1', 'D3BPO4', 'D5AR', 'D5BR', 'RENT_', 'ORIG_FID',
#        'geometry'],
#       dtype='object')

# %%
#bicycle length
folder_path = 'C:/Users/anranzheng/Dropbox (UFL)/Mobility Hub/Data/results/regional/bike2'

shapefile_list = [file for file in os.listdir(folder_path) if file.endswith('.shp')]

merged_gdf = gpd.GeoDataFrame()

for shapefile in shapefile_list:
    gdf = gpd.read_file(os.path.join(folder_path, shapefile))
    
    merged_gdf = merged_gdf.append(gdf, ignore_index=True)
# Out:
# C:\Users\anranzheng\AppData\Local\Temp\ipykernel_28168\1884458222.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   merged_gdf = merged_gdf.append(gdf, ignore_index=True)
# C:\Users\anranzheng\AppData\Local\Temp\ipykernel_28168\1884458222.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   merged_gdf = merged_gdf.append(gdf, ignore_index=True)
# C:\Users\anranzheng\AppData\Local\Temp\ipykernel_28168\1884458222.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   merged_gdf = merged_gdf.append(gdf, ignore_index=True)
# ...

# %%
bike=merged_gdf.groupby(['index'])['Shape_Leng'].sum().reset_index()

# %%
#osm
folder_path = 'C:/Users/anranzheng/Dropbox (UFL)/Mobility Hub/Data/results/regional/osm2'

shapefile_list = [file for file in os.listdir(folder_path) if file.endswith('.shp')]

merged_gdf2 = gpd.GeoDataFrame()

for shapefile in shapefile_list:
    gdf = gpd.read_file(os.path.join(folder_path, shapefile))
    
    merged_gdf2 = merged_gdf2.append(gdf, ignore_index=True)
# Out:
# C:\Users\anranzheng\AppData\Local\Temp\ipykernel_28168\2516433372.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   merged_gdf2 = merged_gdf2.append(gdf, ignore_index=True)
# C:\Users\anranzheng\AppData\Local\Temp\ipykernel_28168\2516433372.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   merged_gdf2 = merged_gdf2.append(gdf, ignore_index=True)
# C:\Users\anranzheng\AppData\Local\Temp\ipykernel_28168\2516433372.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   merged_gdf2 = merged_gdf2.append(gdf, ignore_index=True)
# ...

# %%
osm=merged_gdf2.groupby(['index'])['Shape_Le_1'].sum().reset_index()

# %%
#left join osm with sidewalk and bicycle 
df2 = pd.merge(osm,bike,how='left',on='index')
df2['bike_osm']=df2['Shape_Leng']/df2['Shape_Le_1']
df2=df2.rename(columns={'Shape_Leng':'bike'})
df_all=pd.merge(df2,sum_score,how='left',on='index')

# %%
folder_path = 'C:/Users/anranzheng/Dropbox (UFL)/Mobility Hub/Data/results/regional/access2'

shapefile_list = [file for file in os.listdir(folder_path) if file.endswith('.shp')]

merged_gdf4 = gpd.GeoDataFrame()

for shapefile in shapefile_list:
    gdf = gpd.read_file(os.path.join(folder_path, shapefile))
    #print(shapefile)
    merged_gdf4 = merged_gdf4.append(gdf, ignore_index=True)
# Out:
# C:\Users\anranzheng\AppData\Local\Temp\ipykernel_28168\1296639004.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   merged_gdf4 = merged_gdf4.append(gdf, ignore_index=True)
# C:\Users\anranzheng\AppData\Local\Temp\ipykernel_28168\1296639004.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   merged_gdf4 = merged_gdf4.append(gdf, ignore_index=True)
# C:\Users\anranzheng\AppData\Local\Temp\ipykernel_28168\1296639004.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   merged_gdf4 = merged_gdf4.append(gdf, ignore_index=True)
# ...

# %%
merged_gdf4
# Out:
#      FID_smart_       GEOID10       GEOID20 STATEFP COUNTYFP TRACTCE BLKGRPCE  \
# 0             0  120010009021  120010009021      12      001  000902        1
# 1             2  120010022072  120010022072      12      001  002207        2
# 2             3  120010022181  120010022181      12      001  002218        1
# 3             5  120010022054  120010022054      12      001  002205        4
# 4             6  120010022172  120010022172      12      001  002217        2
# ..          ...           ...           ...     ...      ...     ...      ...
# 584         117  120010005002  120010005002      12      001  000500        2
# 585         118  120010005003  120010005003      12      001  000500        3
# 586         119  120010005005  120010005005      12      001  000500        5
# 587         120  120010007004  120010007004      12      001  000700        4
# 588         121  120010004002  120010004002      12      001  000400        2
#
# ...

# %%
inter_den=merged_gdf4.groupby(['index'])['D3BMM4'].mean().reset_index()

#merge 
final2 = pd.merge(inter_den,df_all,how='left',on='index')

# %%
final3=pd.merge(score,final2,how='left',on='index')[['index', 'inner_micr', 'Route', 'total_trip', 'Total_Acti', 'W_C_TOTAL',
       'BIKE_TOTAL', 'inner_scoo', 'VEHICLE_0%', 'DIS_2064%', 'BELOW_POV%',
       'BLACK%', 'sidewalk', 'sidewalk_o', 'bus_stop_n', 'Walkscore1',
       'D3BPO4', 'D5AR', 'D5BR', 'geometry', 'RENT%', 'D3BMM4', 'bike', 'bike_osm', 'fmlm_score']]

#normalize the selected columns and save to a new df
def normalize(df):
    result = df.copy()
    for feature_name in df.columns:
        max_value = df[feature_name].max()
        min_value = df[feature_name].min()
        result[feature_name] = 100*(df[feature_name] - min_value) / (max_value - min_value)
    return result

df_norm=normalize(final3[['inner_micr', 'Route', 'total_trip', 'Total_Acti', 'W_C_TOTAL',
       'BIKE_TOTAL', 'inner_scoo', 'VEHICLE_0%', 'DIS_2064%', 'BELOW_POV%',
       'BLACK%', 'sidewalk', 'sidewalk_o', 'bus_stop_n', 'Walkscore1',
       'D3BPO4', 'D5AR', 'D5BR', 'RENT%', 'D3BMM4', 'bike', 'bike_osm', 'fmlm_score']])

df_norm['ridership_index']=0.4*df_norm.Total_Acti+0.1*df_norm.W_C_TOTAL+0.1*df_norm.Route+0.1*df_norm.bus_stop_n+0.3*df_norm.total_trip
df_norm['FMLM_index']=0.15*df_norm.inner_micr+0.15*df_norm.inner_scoo+0.15*df_norm.BIKE_TOTAL+0.55*df_norm.fmlm_score
df_norm['infast_index']=0.16*(df_norm.bike_osm+df_norm.bike+df_norm.sidewalk_o+df_norm.sidewalk+df_norm.D3BMM4+df_norm.D3BPO4)
df_norm['socio_index']=0.2*(df_norm['VEHICLE_0%']+df_norm['DIS_2064%']+df_norm['BELOW_POV%']+df_norm['BLACK%']+df_norm['RENT%'])
df_norm['access_index']=0.2*df_norm.D5AR+0.3*df_norm.D5BR+0.5*df_norm.Walkscore1

df_norm['score']=0.125*(df_norm['access_index']+df_norm['FMLM_index']+df_norm['infast_index']+df_norm['socio_index'])+df_norm['ridership_index']*0.5

df_norm =df_norm.sort_values(by='score', ascending=False).head(3)

# %%
df_norm
# Out:
#     inner_micr       Route  total_trip  Total_Acti   W_C_TOTAL  BIKE_TOTAL  \
# 10    13.18002  100.000000   16.666667  100.000000  100.000000    8.659794
# 9      0.00000   85.714286  100.000000   31.496063   16.984733    5.154639
# 4      0.00000   14.285714   72.833333   70.603675    0.000000   48.247423
#
#     inner_scoo  VEHICLE_0%  DIS_2064%  BELOW_POV%  ...     D3BMM4       bike  \
# 10    3.796964   68.347959  95.498902   26.890167  ...  71.251288  67.181647
# 9     3.268500   34.777070  21.473132   72.322008  ...   4.799011  61.467932
# 4     4.935975   43.511142  18.444001  100.000000  ...  30.358957  62.908890
#
#       bike_osm  fmlm_score  ridership_index  FMLM_index  infast_index  \
# 10   44.020735    0.135822        71.761905    3.920219     54.253835
# 9    44.930990   43.475042        57.439756   25.174744     24.512328
# 4   100.000000   37.201808        55.139089   28.438504     30.922856
#
#     socio_index  access_index      score
# ...

# %%
result2=final3[['index','geometry']]

score_df=pd.concat([result2,df_norm],axis=1)

score_df=score_df.dropna()

score_df.to_file('C:/Users/anranzheng/Dropbox (UFL)/Mobility Hub/Data/results/regional/ridership/ridership3.shp')
# Out:
# C:\Users\anranzheng\AppData\Local\Temp\ipykernel_28168\3073672970.py:7: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   score_df.to_file('C:/Users/anranzheng/Dropbox (UFL)/Mobility Hub/Data/results/regional/ridership/ridership3.shp')

# %%
#calculate
score_df['access_index2']=0.33*(score_df.D5AR+score_df.D5BR+score_df.Walkscore1)

score_df['score2']=0.125*(score_df['access_index2']+score_df['FMLM_index']+score_df['infast_index']+score_df['socio_index'])+score_df['ridership_index']*0.5

score_df.sort_values(by='score2', ascending=False).head(1).to_file('C:/Users/anranzheng/Dropbox (UFL)/Mobility Hub/Data/results/regional/ridership/ridership1.shp')
# Out:
# C:\Users\anranzheng\AppData\Local\Temp\ipykernel_28168\4186124216.py:6: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   score_df.sort_values(by='score2', ascending=False).head(1).to_file('C:/Users/anranzheng/Dropbox (UFL)/Mobility Hub/Data/results/regional/ridership/ridership1.shp')
