# %%
import pandas as pd
import geopandas as gpd
from shapely.geometry import Point
import glob,os

# %%
folder_path = 'C:/Users/anranzheng/Dropbox (UFL)/Mobility Hub/Data/process data/road/socioeconomic/tract'

shapefile_list = [file for file in os.listdir(folder_path) if file.endswith('.shp')]

merged_gdf = gpd.GeoDataFrame()

for shapefile in shapefile_list:
    gdf = gpd.read_file(os.path.join(folder_path, shapefile))
    
    merged_gdf = merged_gdf.append(gdf, ignore_index=True)
# Out:
# C:\Users\anranzheng\AppData\Local\Temp\ipykernel_2548\459886670.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   merged_gdf = merged_gdf.append(gdf, ignore_index=True)
# C:\Users\anranzheng\AppData\Local\Temp\ipykernel_2548\459886670.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   merged_gdf = merged_gdf.append(gdf, ignore_index=True)
# C:\Users\anranzheng\AppData\Local\Temp\ipykernel_2548\459886670.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   merged_gdf = merged_gdf.append(gdf, ignore_index=True)
# ...

# %%
df=merged_gdf.groupby(['FID_result'])['HISPNC_NOT','TOTALPOP','HOUSEHOLDS','VEHICLE_0','BACHELORS','AGE_UNDER5','AGE_65_UP','DIS_2064','S_NOTATALL','BELOW_POV'].sum().reset_index()
# Out:
# C:\Users\anranzheng\AppData\Local\Temp\ipykernel_2548\3290349842.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df=merged_gdf.groupby(['FID_result'])['HISPNC_NOT','TOTALPOP','HOUSEHOLDS','VEHICLE_0','BACHELORS','AGE_UNDER5','AGE_65_UP','DIS_2064','S_NOTATALL','BELOW_POV'].sum().reset_index()

# %% [markdown]
# https://fdotwww.blob.core.windows.net/sitefinity/docs/default-source/planning/policy/public-involvement/fdot-bdv29-977-32-rpt.pdf?sfvrsn=9eff0f7b_2

# %%
df['HISPNC_NOT%']=df['HISPNC_NOT']*100/df['TOTALPOP']
df['VEHICLE_0%']=df['VEHICLE_0']*100/df['HOUSEHOLDS']
df['BACHELORS%']=df['BACHELORS']*100/df['TOTALPOP']
df['AGE_UNDER5%']=df['AGE_UNDER5']*100/df['TOTALPOP']
df['AGE_65_UP%']=df['AGE_65_UP']*100/df['TOTALPOP']
df['DIS_2064%']=df['DIS_2064']*100/df['TOTALPOP']
df['S_NOTATALL%']=df['S_NOTATALL']*100/df['TOTALPOP']
df['BELOW_POV%']=df['BELOW_POV']*100/df['TOTALPOP']

# %%
df.head()
# Out:
#    FID_result  HISPNC_NOT  TOTALPOP  HOUSEHOLDS  VEHICLE_0  BACHELORS  \
# 0           0       19978     23951       10102        954       3221
# 1           1       18635     22289        9488        919       3007
# 2           2       23249     27667       11548       1116       3486
# 3           3       21954     26010       10866       1108       3404
# 4           4       25485     30347       11909       1378       3510
#
#    AGE_UNDER5  AGE_65_UP  DIS_2064  S_NOTATALL  BELOW_POV  HISPNC_NOT%  \
# 0        1059       1786      1115          58       8854     0.834120
# 1         903       1523      1039          58       8204     0.836063
# 2         961       1596      1228          77      10925     0.840315
# 3         916       1596      1198          77      10354     0.844060
# 4         956       1398      1324          77      11614     0.839786
#
#    VEHICLE_0%  BACHELORS%  AGE_UNDER5%  AGE_65_UP%  DIS_2064%  S_NOTATALL%  \
# ...

# %%
unit=gpd.read_file('C:/Users/anranzheng/Dropbox (UFL)/Mobility Hub/Data/process data/fmlm/result.shp')

# %%
new_df = pd.merge(unit,df,how='left',left_on='ORIG_FID',right_on='FID_result')
new_df.to_file('C:/Users/anranzheng/Dropbox (UFL)/Mobility Hub/Data/process data/road/socioeconomic/result2.shp')
# Out:
# C:\Users\anranzheng\AppData\Local\Temp\ipykernel_2548\504471900.py:2: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   new_df.to_file('C:/Users/anranzheng/Dropbox (UFL)/Mobility Hub/Data/process data/road/socioeconomic/result2.shp')
